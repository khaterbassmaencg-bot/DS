# %% [markdown]
# <a href="https://colab.research.google.com/github/khaterbassmaencg-bot/DS/blob/main/Python_Learning_%26_Exam_Performance_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Python Learning & Exam Performance Dataset")
print(df.columns)
/content/drive/MyDrive/Colab Notebooks/Python Learning & Exam Performance Dataset
